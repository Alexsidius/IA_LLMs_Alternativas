# %%
#importar o dotenv para fazer peitura das chaves no arquivo .env
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
import os
api_key = os.getenv("GEMINI_API_KEY")

# %%
import google.generativeai as genai
genai.configure(api_key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import google.generativeai as genai
#       2 genai.configure(api_key)
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\generativeai\__init__.py:45
#      41 from __future__ import annotations
#      43 from google.generativeai import version
# ---> 45 from google.generativeai import caching
#      46 from google.generativeai import protos
#      47 from google.generativeai import types
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\generativeai\caching.py:21
#      18 import textwrap
#      19 from typing import Iterable, Optional
# ---> 21 from google.generativeai import protos
#      22 from google.generativeai.types import caching_types
#      23 from google.generativeai.types import content_types
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\generativeai\protos.py:74
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2024 Google LLC
#       3 #
#    (...)     13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      15 """
#      16 This module provides low level access to the ProtoBuffer "Message" classes used by the API.
#      17
#    (...)     71 >>> help(proto.Part.to_dict)
#      72 """
# ---> 74 from google.ai.generativelanguage_v1beta.types import *
#      75 from google.ai.generativelanguage_v1beta.types import __all__
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\__init__.py:21
#      16 from google.ai.generativelanguage_v1beta import gapic_version as package_version
#      18 __version__ = package_version.__version__
# ---> 21 from .services.cache_service import CacheServiceAsyncClient, CacheServiceClient
#      22 from .services.discuss_service import DiscussServiceAsyncClient, DiscussServiceClient
#      23 from .services.file_service import FileServiceAsyncClient, FileServiceClient
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\cache_service\__init__.py:16
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2024 Google LLC
#       3 #
#    (...)     14 # limitations under the License.
#      15 #
# ---> 16 from .async_client import CacheServiceAsyncClient
#      17 from .client import CacheServiceClient
#      19 __all__ = (
#      20     "CacheServiceClient",
#      21     "CacheServiceAsyncClient",
#      22 )
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\cache_service\async_client.py:32
#      18 import re
#      19 from typing import (
#      20     Callable,
#      21     Dict,
#    (...)     29     Union,
#      30 )
# ---> 32 from google.api_core import exceptions as core_exceptions
#      33 from google.api_core import gapic_v1
#      34 from google.api_core import retry_async as retries
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\api_core\exceptions.py:29
#      26 from typing import Union
#      27 import warnings
# ---> 29 from google.rpc import error_details_pb2
#      32 def _warn_could_not_import_grpcio_status():
#      33     warnings.warn(
#      34         "Please install grpcio-status to obtain helpful grpc error messages.",
#      35         ImportWarning,
#      36     )  # pragma: NO COVER
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\rpc\error_details_pb2.py:21
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright 2025 Google LLC
#    (...)     18 # source: google/rpc/error_details.proto
#      19 # Protobuf Python Version: 4.25.3
#      20 """Generated protocol buffer code."""
# ---> 21 from google.protobuf import descriptor as _descriptor
#      22 from google.protobuf import descriptor_pool as _descriptor_pool
#      23 from google.protobuf import symbol_database as _symbol_database
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\protobuf\descriptor.py:17
#      14 import threading
#      15 import warnings
# ---> 17 from google.protobuf.internal import api_implementation
#      19 _USE_C_DESCRIPTORS = False
#      20 if api_implementation.Type() != 'python':
#      21   # Used by MakeDescriptor in cpp mode
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\protobuf\internal\api_implementation.py:51
#      47     return False
#      50 if _implementation_type is None:
# ---> 51   if _CanImport('google._upb._message'):
#      52     _implementation_type = 'upb'
#      53   elif _CanImport('google.protobuf.pyext._message'):
#
# File h:\Projetos VSCode\IA_LLMs_Alternativas\.venv\Lib\site-packages\google\protobuf\internal\api_implementation.py:41, in _CanImport(mod_name)
#      39 def _CanImport(mod_name):
#      40   try:
# ---> 41     mod = importlib.import_module(mod_name)
#      42     # Work around a known issue in the classic bootstrap .par import hook.
#      43     if not mod:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# TypeError: Metaclasses with custom tp_new are not supported.
