# %%
#importar o dotenv para fazer peitura das chaves no arquivo .env
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
import os
api_key = os.getenv("GEMINI_API_KEY")

# %%
import google.generativeai as genai
genai.configure(api_key=api_key)

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")
response = model.generate_content("Qual dica você me recomenda para ser mais produtivo nos estudos")

# %%
import textwrap

def formatacao_texto(response):

    text = response
    text_formatted = textwrap.fill(text, width=100)
    print(text_formatted)

# %%
formatacao_texto(response.text)
# Out:
# Para ser mais produtivo nos estudos, a dica mais poderosa que posso te dar é: **combine planejamento
# estratégico com estudo ativo e foco na sua energia.**  Vamos detalhar isso em algumas estratégias
# práticas:  1.  **Planejamento e Organização (Antes de Começar):**     *   **Defina Metas Claras e
# Pequenas:** Em vez de "Estudar Matemática", defina "Resolver 10 exercícios de Equações de 2º Grau"
# ou "Ler e resumir o Capítulo 3 de Biologia". Metas pequenas são menos intimidantes e te dão uma
# sensação de progresso.     *   **Crie um Cronograma Realista:** Use uma agenda ou planner. Distribua
# as matérias e tarefas ao longo da semana, deixando blocos de tempo dedicados. Seja realista com o
# tempo que você tem e as pausas necessárias.     *   **Priorize:** Use a Matriz de Eisenhower
# (Urgente/Importante) ou simplesmente comece pelas tarefas mais difíceis ou que você menos gosta.
# ...

# %% [markdown]
# ### Leitura de imagens

# %%
import httpx
import os
import base64
import google.generativeai as genai

genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

model = genai.GenerativeModel("models/gemini-2.5-flash")

# URL RAW do GitHub (correta!)
image_url = "https://raw.githubusercontent.com/Alexsidius/IA_LLMs_Alternativas/master/files/imagemCD.png"

# Baixa a imagem
image = httpx.get(image_url).content

# Converte para Base64
image_b64 = base64.b64encode(image).decode("utf-8")

prompt = "Descreva a imagem."

# Envia apenas UMA parte de imagem + o prompt
response = model.generate_content([
    {"mime_type": "image/png", "data": image_b64},
    {"text": prompt}
])

print(response.text)
# Out:
# Esta imagem retrata uma cena romântica e cheia de alegria ao ar livre, banhada pela luz dourada do que parece ser o pôr do sol ou o nascer do sol.
#
# No centro-direita da imagem, um casal está dançando com entusiasmo. O homem, ligeiramente mais à esquerda, segura as mãos da mulher acima da sua cabeça, enquanto a gira. A mulher está com o corpo ligeiramente inclinado para trás e o cabelo voando, o que transmite a sensação de movimento e liberdade. Ambos estão vestidos casualmente e aparecem em silhueta contra o sol forte, embora os contornos de suas roupas sejam visíveis.
#
# A luz do sol é uma característica dominante, posicionada atrás do casal e ligeiramente à esquerda, criando um brilho intenso e uma atmosfera quente e etérea. O céu é preenchido por tons vibrantes de laranja, amarelo e dourado, que se suavizam à medida que se afastam do sol.
#
# ...

# %%
#exibicao da imagem descrita acima
from IPython.display import Markdown, display
raw_url = "https://raw.githubusercontent.com/Alexsidius/IA_LLMs_Alternativas/master/files/imagemCD.png"
display(Markdown(f"![]({raw_url})"))
# Out:
# ![](https://raw.githubusercontent.com/Alexsidius/IA_LLMs_Alternativas/master/files/imagemCD.png)
